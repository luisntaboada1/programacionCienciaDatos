# %% [markdown]
# ***PROCESOS EXPLICADOS***
# PARCIAL 1

# %% [markdown]
# **TAREA 1**

# %% [markdown]
# ![2025-10-14_17h20_08.png](attachment:ad2725b2-e65b-4ca7-afb1-1ec8b3db2f8e.png)

# %% [markdown]
# 1.1 Primero cree el repositorio en Github y fue ahi donde genere el README.md
#    ![creacion_repo.png](attachment:372fd584-7e26-45b8-969a-666c2411f3b4.png)

# %% [markdown]
# 1.2 Despues hice una carpeta local donde inicialize un git. Luego ligue el repositorio remoto con el git recien inicializado e hice un pull para bajar el readme.md y los cambios
#    ![2025-10-14_15h28_02.png](attachment:fe3ed7a8-7487-4bb4-b022-ff3ec4507c6a.png)

# %% [markdown]
# 1.3. Despues intente hacer un primer commit tras resolver un conflicto. Aunque yo nunca haya creado una rama, el git local estaba por defecto en una rama llamada master y el repositorio en github estaba en main.
#    ![2025-10-14_15h38_47.png](attachment:779e35b1-d41a-4af1-9f69-565b1c6adce7.png)

# %% [markdown]
# 1.4. Lo resolvi cambiando el nombre de la rama local master a main. Despues de eso el push al remoto funciono
#     ![2025-10-14_15h40_24.png](attachment:0b788dec-9f93-438d-a1af-946a01204c85.png)

# %% [markdown]
# 1.5. Despues de eso hice los otros 2 commits necesarios y los subi al github
#
# ![2025-10-14_15h50_46.png](attachment:37199853-b996-417b-a016-80445ba3ce4f.png)

# %% [markdown]
# **TAREA 2**
#
#
# ![image.png](attachment:99aef95d-6808-4af9-85a8-8c0b04739711.png)

# %% [markdown]
# 2.1. Cree la rama docs y subi los cambios a github
#
# ![2025-10-14_16h12_30.png](attachment:e68e8316-3529-4a1d-b1af-74e1aff47755.png)

# %% [markdown]
# 2.2. Agregue la seccion de Objetivos personales al readme, guarde y subi los cambios a la rama docs en github
# ![2025-10-14_16h12_30.png](attachment:aa75a14f-5188-4902-9557-8e2458752aa8.png)

# %% [markdown]
# 2.3. Me cambie a la rama principal y la junte con docs
#
# ![2025-10-14_16h12_30.png](attachment:3e988c3d-7900-428e-b1aa-f8a052198a63.png)

# %% [markdown]
# **TAREA 3**
#
# ![image.png](attachment:5a69fc5e-f125-4f03-9a4c-01957529d71c.png)

# %% [markdown]
# 3.1. Cree el archivo proceso.md con lo solicitado, las carpetas se piden (notebooks, datasets y proyectos) pero de estas ultimas solo aparece notebooks en github. Sospecho que es por que las otras 2 siguen vacias
# Tambien agregue lo que se pide al readme.
#  ![image.png](attachment:b975f661-a620-4c9d-a837-509cc357f88d.png)

# %% [markdown]
# 3.2. Hice un pull request desde una cuenta y lo acepte con otra.
#
# ![2025-10-14_17h08_35.png](attachment:92eabc4b-b5de-4bfb-b1ff-ec3771062201.png)
#
#
# ![2025-10-14_17h08_52.png](attachment:0db6e07f-e80f-48b8-b94d-99406ad57d73.png)
